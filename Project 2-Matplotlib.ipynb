# %% [markdown]
# # Assignment-2 Matplotlib: List the causes of death and percentile in Ohio state in the year 2012

# %%
#import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns

# %%
# View the plot
# %matplotlib inline

# %%
#cause of deaths
cause_of_deaths="Chronic Disease", "Unintetional Injuries", "Alzheimers", "Infuenza and Pneumonia","Sepsis","Others"
#percentile
percentile=[62, 5, 4, 2, 1 , 26]

# %% [markdown]
# #### 2: Draw a pie chart using the two data points

# %%
#set the pie chart plot properties
colors=["Brown","Red","Yellow","Grey","Purple","Pink"]

# %%
#set figure size
plt.figure(figsize=(10,5))
#explode the largest pie in the data set
explode=(0.05,0.08,0.06,0.07,0.09,0.08) 
#set pie chart properties
plt.pie(percentile,labels=cause_of_deaths,explode=explode,colors=colors,autopct='%1.1f%%',startangle=180)
#set axis equal to draw pie as circle
plt.axis("equal")
#set title of the pie chart
plt.title("Cause of death")
#show the plot (pie chart)
plt.legend()
plt.show()

# %% [markdown]
# ### THE END
